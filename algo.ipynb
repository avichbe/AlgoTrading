# %%
import pandas as pd

# %%
pd.core.common.is_list_like = pd.api.types.is_list_like

# %%
from pandas_datareader import data
df = data.get_data_yahoo('NDX', '2008-01-01', '2020-04-01')
df1 = data.get_data_yahoo('GOOG', '2008-01-01', '2020-04-01')
df.head()
# Out:
#                    High          Low  ...  Volume    Adj Close
# Date                                  ...
# 2008-02-22  1773.439941  1773.439941  ...     0.0  1773.439941
# 2008-03-05  1753.569946  1753.569946  ...     0.0  1753.569946
# 2008-03-12  1735.180054  1735.180054  ...     0.0  1735.180054
# 2008-07-25  1846.550049  1846.550049  ...     0.0  1846.550049
# 2008-08-25  1889.719971  1889.719971  ...     0.0  1889.719971
#
# [5 rows x 6 columns]

# %%
info={}
for i in ['GOOG','VIX', 'NDX']:
    info [i]= data.get_data_yahoo(i, '2008-01-01', '2020-04-01')
print(info)
# Out:
# {'GOOG':                    High          Low  ...      Volume    Adj Close
# Date                                  ...
# 2008-01-02   347.382935   337.599579  ...   8646000.0   341.315674
# 2008-01-03   342.142578   336.996857  ...   6529300.0   341.385406
# 2008-01-04   339.208557   326.277039  ...  10759700.0   327.273285
# 2008-01-07   329.903442   317.484985  ...  12854700.0   323.412781
# 2008-01-08   328.747772   314.321838  ...  10718100.0   314.660583
# ...                 ...          ...  ...         ...          ...
# 2020-03-26  1169.969971  1093.530029  ...   3571700.0  1161.750000
# 2020-03-27  1150.670044  1105.910034  ...   3208500.0  1110.709961
# 2020-03-30  1151.630005  1096.479980  ...   2574100.0  1146.819946
# 2020-03-31  1175.310059  1138.140015  ...   2486400.0  1162.810059
# 2020-04-01  1129.689941  1097.449951  ...   2344200.0  1105.619995
#
# [3084 rows x 6 columns], 'VIX':                     High           Low  ...    Volume     Adj Close
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

plt.figure(figsize=(14,6))

# Add title
plt.title("Daily Global Streams of Popular Songs in 2017-2018")

# Line chart showing daily global streams of 'Shape of You'
sns.lineplot(data=df['Close'], label="NDX")
sns.lineplot(data=df1['Close'], label="GOOG")
# Line chart showing daily global streams of 'Despacito'

sns.regplot(x=df1['Close'], y=df['Close'])
# Add label for horizontal axis
plt.xlabel("Date")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-bea660d79a92> in <module>()
#      13 # Line chart showing daily global streams of 'Despacito'
#      14
# ---> 15 sns.regplot(x=df1['Close'], y=df['Close'])
#      16 # Add label for horizontal axis
#      17 plt.xlabel("Date")
#
# /usr/local/lib/python3.6/dist-packages/seaborn/regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     808                                  order, logistic, lowess, robust, logx,
#     809                                  x_partial, y_partial, truncate, dropna,
# --> 810                                  x_jitter, y_jitter, color, label)
#     811
#     812     if ax is None:
#
# ...
